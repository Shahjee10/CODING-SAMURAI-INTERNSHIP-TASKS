# %%
pip install scikit-learn
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 2.5 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.7 MB 2.7 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.7 MB 3.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.7 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.7/8.7 MB 3.3 MB/s eta 0:00:02
#    -------------------- ------------------- 4.5/8.7 MB 3.5 MB/s eta 0:00:02
#    ------------------------- -------------- 5.5/8.7 MB 3.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.3/8.7 MB 3.7 MB/s eta 0:00:01
# ...

# %% [markdown]
# # 🧠 Simple Linear Regression Project
#
# ### Coding Samurai Internship Task
#
# This notebook is part of my **Data Science Internship at Coding Samurai**. It demonstrates how to perform **Simple Linear Regression** using Python and Scikit-Learn to predict house prices based on area.
#
# ---

# %% [markdown]
# ## 📂 Step 1: Import Required Libraries
#
# In this section, we import all the necessary Python libraries for data handling, visualization, and model building.

# %% [markdown]
# import pandas as pd # For handling and reading data
# import numpy as np    # For numerical calculations
# import matplotlib.pyplot as plt # For data visualization
# from sklearn import linear_model  # For performing linear regression

# %% [markdown]
# ## 📊 Step 2: Load the Dataset
#
# We load the dataset containing information about house areas and their respective prices.

# %%
df = pd.read_excel(r"C:\Users\hp\Downloads\homeprices.csv.xlsx")

# %%
# Displaying the first few rows to understand the structure of data
print(df)
# Out:
#     area        Prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   4490  7.903031e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %% [markdown]
# ## 🧮 Step 3: Model Training (Linear Regression)
#
# We train a simple linear regression model to learn the relationship between house area and price.

# %% [markdown]
#  %matplotlib inline
# plt.xlabel('area(sqr ft)')
# plt.ylabel('price(US$)')
# plt.scatter(df.area,df.price,color='red',marker='+')

# %%
## Creating an instance for Linear Regression Model
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.Prices)
# Out:
# LinearRegression()

# %%
## Testing the prediction model
reg.predict([[1100]])
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([329982.87671233])

# %%
df.head(3)
# Out:
#    area         Prices
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192

# %% [markdown]
# ## 📈 Step 4: Visualization
#
# We visualize the actual data points and the regression line to see how well the model fits the data.

# %%
# Scatter plot of actual data
plt.scatter(df['area'], df['Prices'], color='blue', label='Actual Data')

# Plot regression line using model predictions
plt.plot(df['area'], reg.predict(df[['area']]), color='red', label='Regression Line')

# Add labels, title, and legend
plt.xlabel('Area (sq ft)')
plt.ylabel('Price ($)')
plt.title('Linear Regression: Area vs Price')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# ### 🎯 Conclusion
# This project demonstrates how **Simple Linear Regression** can be used to predict continuous values like house prices. It was completed as part of my **Coding Samurai Data Science Internship** to strengthen my understanding of machine learning fundamentals using Python.
#
# 📌 **Developed by:** Syed Ahmed Ali Shah
